# %%
# %matplotlib widget
import sys
import os
import time
import numpy as np
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Set the GPU you wish to use here
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], enable=True)

import tensorflow_addons as tfa
from tensorflow.python.keras import Input
from tensorflow.keras.models import Sequential, Model
from tensorflow.python.keras.layers import Conv1D, GlobalAveragePooling1D, AveragePooling1D, MaxPool1D, Flatten, Dense, \
    Reshape, Dropout, TimeDistributed, Add, LSTM, GRU, Bidirectional, MaxPooling1D, Reshape
from tensorflow.python.keras.layers import LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow.python.keras as keras
tf.keras.backend.clear_session()

# %%
import tensorflow as tf
from tensorflow.python.keras import Input
from tensorflow.keras.models import Model
from tensorflow.python.keras.layers import Conv1D, GlobalAveragePooling1D, AveragePooling1D, MaxPool1D, Flatten, Dense, \
    Reshape, Dropout, TimeDistributed, Add, LSTM, GRU, Bidirectional
from tensorflow.python.keras.layers import LeakyReLU


def dilated_residual_convolution(X_in, kernel, dilations, dropout, name="", l1=0):
    X = X_in
    for i, dilation in enumerate(dilations):
        X = TimeDistributed(
            Conv1D(X_in.shape[-1], kernel_size=kernel, dilation_rate=dilation, padding='same',
                   kernel_regularizer=tf.keras.regularizers.l1(l=l1)),
            name=f"{name}_Conv{i}")(X)
        X = TimeDistributed(LeakyReLU(alpha=0.15))(X)
    X = Add(name=f"{name}_Addition")([X, X_in])
    if dropout > 0:
        X = TimeDistributed(Dropout(dropout), name=f"{name}_Dropout")(X)
    return X


def residual_convolution(X_in, kernel, filt, n_convs, name=None, l1=0):
    X = X_in
    # Residual needs 1x1 CNN
    X_residual = Conv1D(filt, 1, activation='relu', padding='same', name=f"{name}_residual_1x1Conv")(X)
    X_residual = MaxPool1D(2, strides=2, name=f"{name}_residual_Maxpool")(X_residual)

    # Convolutions and max pooling
    for i in range(n_convs):
        X = Conv1D(filt, kernel, kernel_regularizer=tf.keras.regularizers.l1(l=l1), padding='same',
                            name=f"{name}_Conv{i}")(X)
        X = LeakyReLU(alpha=0.15)(X)

    # Bring in the residual
    X = MaxPool1D(2, strides=2, name=f"{name}_Maxpool")(X)
    X = Add(name=f"{name}_residual_Add")([X, X_residual])

    return X


def convolution(X_in, kernel, filt, n_convs=1, name=None, l1=0):
    X = X_in
    for i in range(n_convs):
        X = Conv1D(filt, kernel, padding='same', kernel_regularizer=tf.keras.regularizers.l1(l=l1),
                            name=f"{name}_Conv{i}")(X)
        X = LeakyReLU(alpha=0.15)(X)
    X = MaxPool1D(2, strides=2, name=f"{name}_maxpool")(X)
    return X


def google_signal_model(shape, params):
    print("Building Model", end="")
    inputs = Input(shape=(shape[1], 1))

    X = Conv1D(8, 21, padding='same', kernel_regularizer =tf.keras.regularizers.l1(l=params['l1']), name="InputConv1")(inputs)
    X = Conv1D(64, 21, strides=5, padding='same', kernel_regularizer =tf.keras.regularizers.l1(l=params['l1']), name="InputConv2")(X)

    X = residual_convolution(X, kernel=params['conv_kernel'], filt=params['conv_filters_base']*, n_convs=2, name="ConvBlock1", l1=params['l1'])
    X = residual_convolution(X, kernel=params['conv_kernel'], filt=params['conv_filters_base']*2, n_convs=2, name="ConvBlock2",l1=params['l1'])
    X = residual_convolution(X, kernel=params['conv_kernel'], filt=params['conv_filters_base']*4, n_convs=2, name="ConvBlock3",l1=params['l1'])
    X = residual_convolution(X, kernel=params['conv_kernel'], filt=params['conv_filters_base']*8, n_convs=2, name="ConvBlock4",l1=params['l1'])
    X = residual_convolution(X, kernel=params['conv_kernel'], filt=params['conv_filters_base']*16, n_convs=2, name="ConvBlock5",l1=params['l1'])
    X = residual_convolution(X, kernel=params['conv_kernel'], filt=params['conv_filters_base']*16, n_convs=2, name="ConvBlock6",l1=params['l1'])
    X = MaxPool1D(3, strides=3, name=f"Final_Maxpool")(X)
    X = Reshape(target_shape=(params['memory_time_steps'], int(X.shape[1]/params['memory_time_steps']), params['conv_filters_base']*16))(X)
    X = TimeDistributed(Flatten(), name=f"Flatten")(X)
    # X = TimeDistributed(Dropout(params['dropout']), name=f"DropoutD1")(X)
    X = TimeDistributed(Dense(units=params['dense1']), name=f"Dense1")(X)
    X = TimeDistributed(LeakyReLU(alpha=0.15))(X)
    # X = TimeDistributed(Dropout(params['dropout']), name=f"DropoutD2")(X)

    if params['use_dense2']:
        X = TimeDistributed(Dense(units=params['dense2']), name=f"Dense2")(X)
        X = TimeDistributed(LeakyReLU(alpha=0.15))(X)


    X = Reshape(target_shape=(1, X.shape[1], X.shape[2]))(X)

    X = dilated_residual_convolution(X, kernel=int(params['dilated_kernel']), dilations=[2, 4, 8, 16, 32], dropout=params['dropout'], l1=params['l1'], name="Dilated1")
    if params['use_dilated_2']:
        X = dilated_residual_convolution(X, kernel=int(params['dilated_kernel']), dilations=[2, 4, 8, 16, 32], dropout=params['dropout'], l1=params['l1'], name="Dilated2")
    if params['use_dilated_3']:
        X = dilated_residual_convolution(X, kernel=int(params['dilated_kernel']), dilations=[2, 4, 8, 16, 32], dropout=params['dropout'], l1=params['l1'], name="Dilated3")

    out = TimeDistributed(Conv1D(4, 1, activation='softmax'))(X)

    model = Model(inputs=inputs, outputs=out)

    model.compile(optimizer=tf.keras.optimizers.Adam(lr=params['learning_rate']),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  metrics=['accuracy'],
                  sample_weight_mode="temporal")
    print("Model Compiled")
    return model

# %%
in_shape = (100, 1152000, 1)
model_params = {'verbose': 1, 'model_checkpoints': '/home/kkotzen/tmp/models', 'memory_time_steps': 1200, 'learning_rate': 0.0001, 'epochs': 80, 'batch_size': 1, 'es_mc': True, 'es_mc_metric': 'kappa', 'evaluation_set': 'validate', 'dropout': 0.45, 'weight_wake': 1.0, 'weight_light': 1.0, 'weight_deep': 4.0, 'weight_rem': 1.0, 'input_convs': 8, 'input_kernel': 1, 'conv_kernel': 7, 'conv_filters_base': 16, 'dense1': 128, 'use_dense2': False, 'dense2': 64, 'dilated_kernel': 7, 'use_dilated_2': True, 'use_dilated_3': False, 'l2': 0, 'l1': 0}
model = google_signal_model(in_shape, model_params)
model.summary()
# Out:
# Building ModelModel Compiled
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 1152000, 1)] 0
# __________________________________________________________________________________________________
# InputConv1 (Conv1D)             (None, 1152000, 8)   176         input_2[0][0]
# __________________________________________________________________________________________________
# InputConv2 (Conv1D)             (None, 230400, 64)   10816       InputConv1[0][0]
# __________________________________________________________________________________________________
# ConvBlock1_Conv0 (Conv1D)       (None, 230400, 16)   7184        InputConv2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 230400, 16)   0           ConvBlock1_Conv0[0][0]
# __________________________________________________________________________________________________
# ConvBlock1_Conv1 (Conv1D)       (None, 230400, 16)   1808        leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 230400, 16)   0           ConvBlock1_Conv1[0][0]
# __________________________________________________________________________________________________
# ConvBlock1_residual_1x1Conv (Co (None, 230400, 16)   1040        InputConv2[0][0]
# __________________________________________________________________________________________________
# ConvBlock1_Maxpool (MaxPooling1 (None, 115200, 16)   0           leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# ConvBlock1_residual_Maxpool (Ma (None, 115200, 16)   0           ConvBlock1_residual_1x1Conv[0][0]
# __________________________________________________________________________________________________
# ConvBlock1_residual_Add (Add)   (None, 115200, 16)   0           ConvBlock1_Maxpool[0][0]
#                                                                  ConvBlock1_residual_Maxpool[0][0]
# __________________________________________________________________________________________________
# ConvBlock2_Conv0 (Conv1D)       (None, 115200, 32)   3616        ConvBlock1_residual_Add[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 115200, 32)   0           ConvBlock2_Conv0[0][0]
# __________________________________________________________________________________________________
# ConvBlock2_Conv1 (Conv1D)       (None, 115200, 32)   7200        leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 115200, 32)   0           ConvBlock2_Conv1[0][0]
# __________________________________________________________________________________________________
# ConvBlock2_residual_1x1Conv (Co (None, 115200, 32)   544         ConvBlock1_residual_Add[0][0]
# __________________________________________________________________________________________________
# ConvBlock2_Maxpool (MaxPooling1 (None, 57600, 32)    0           leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# ConvBlock2_residual_Maxpool (Ma (None, 57600, 32)    0           ConvBlock2_residual_1x1Conv[0][0]
# __________________________________________________________________________________________________
# ConvBlock2_residual_Add (Add)   (None, 57600, 32)    0           ConvBlock2_Maxpool[0][0]
#                                                                  ConvBlock2_residual_Maxpool[0][0]
# __________________________________________________________________________________________________
# ConvBlock3_Conv0 (Conv1D)       (None, 57600, 64)    14400       ConvBlock2_residual_Add[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 57600, 64)    0           ConvBlock3_Conv0[0][0]
# __________________________________________________________________________________________________
# ConvBlock3_Conv1 (Conv1D)       (None, 57600, 64)    28736       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 57600, 64)    0           ConvBlock3_Conv1[0][0]
# __________________________________________________________________________________________________
# ConvBlock3_residual_1x1Conv (Co (None, 57600, 64)    2112        ConvBlock2_residual_Add[0][0]
# __________________________________________________________________________________________________
# ConvBlock3_Maxpool (MaxPooling1 (None, 28800, 64)    0           leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# ConvBlock3_residual_Maxpool (Ma (None, 28800, 64)    0           ConvBlock3_residual_1x1Conv[0][0]
# __________________________________________________________________________________________________
# ConvBlock3_residual_Add (Add)   (None, 28800, 64)    0           ConvBlock3_Maxpool[0][0]
#                                                                  ConvBlock3_residual_Maxpool[0][0]
# __________________________________________________________________________________________________
# ConvBlock4_Conv0 (Conv1D)       (None, 28800, 128)   57472       ConvBlock3_residual_Add[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 28800, 128)   0           ConvBlock4_Conv0[0][0]
# __________________________________________________________________________________________________
# ConvBlock4_Conv1 (Conv1D)       (None, 28800, 128)   114816      leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 28800, 128)   0           ConvBlock4_Conv1[0][0]
# __________________________________________________________________________________________________
# ConvBlock4_residual_1x1Conv (Co (None, 28800, 128)   8320        ConvBlock3_residual_Add[0][0]
# __________________________________________________________________________________________________
# ConvBlock4_Maxpool (MaxPooling1 (None, 14400, 128)   0           leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# ConvBlock4_residual_Maxpool (Ma (None, 14400, 128)   0           ConvBlock4_residual_1x1Conv[0][0]
# __________________________________________________________________________________________________
# ConvBlock4_residual_Add (Add)   (None, 14400, 128)   0           ConvBlock4_Maxpool[0][0]
#                                                                  ConvBlock4_residual_Maxpool[0][0]
# __________________________________________________________________________________________________
# ConvBlock5_Conv0 (Conv1D)       (None, 14400, 256)   229632      ConvBlock4_residual_Add[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 14400, 256)   0           ConvBlock5_Conv0[0][0]
# __________________________________________________________________________________________________
# ConvBlock5_Conv1 (Conv1D)       (None, 14400, 256)   459008      leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 14400, 256)   0           ConvBlock5_Conv1[0][0]
# __________________________________________________________________________________________________
# ConvBlock5_residual_1x1Conv (Co (None, 14400, 256)   33024       ConvBlock4_residual_Add[0][0]
# __________________________________________________________________________________________________
# ConvBlock5_Maxpool (MaxPooling1 (None, 7200, 256)    0           leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# ConvBlock5_residual_Maxpool (Ma (None, 7200, 256)    0           ConvBlock5_residual_1x1Conv[0][0]
# __________________________________________________________________________________________________
# ConvBlock5_residual_Add (Add)   (None, 7200, 256)    0           ConvBlock5_Maxpool[0][0]
#                                                                  ConvBlock5_residual_Maxpool[0][0]
# __________________________________________________________________________________________________
# ConvBlock6_Conv0 (Conv1D)       (None, 7200, 256)    459008      ConvBlock5_residual_Add[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 7200, 256)    0           ConvBlock6_Conv0[0][0]
# __________________________________________________________________________________________________
# ConvBlock6_Conv1 (Conv1D)       (None, 7200, 256)    459008      leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 7200, 256)    0           ConvBlock6_Conv1[0][0]
# __________________________________________________________________________________________________
# ConvBlock6_residual_1x1Conv (Co (None, 7200, 256)    65792       ConvBlock5_residual_Add[0][0]
# __________________________________________________________________________________________________
# ConvBlock6_Maxpool (MaxPooling1 (None, 3600, 256)    0           leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# ConvBlock6_residual_Maxpool (Ma (None, 3600, 256)    0           ConvBlock6_residual_1x1Conv[0][0]
# __________________________________________________________________________________________________
# ConvBlock6_residual_Add (Add)   (None, 3600, 256)    0           ConvBlock6_Maxpool[0][0]
#                                                                  ConvBlock6_residual_Maxpool[0][0]
# __________________________________________________________________________________________________
# Final_Maxpool (MaxPooling1D)    (None, 1200, 256)    0           ConvBlock6_residual_Add[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1200, 1, 256) 0           Final_Maxpool[0][0]
# __________________________________________________________________________________________________
# Flatten (TimeDistributed)       (None, 1200, 256)    0           reshape_2[0][0]
# __________________________________________________________________________________________________
# Dense1 (TimeDistributed)        (None, 1200, 128)    32896       Flatten[0][0]
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (None, 1200, 128)    0           Dense1[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1200, 128) 0           time_distributed_12[0][0]
# __________________________________________________________________________________________________
# Dilated1_Conv0 (TimeDistributed (None, 1, 1200, 128) 114816      reshape_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (None, 1, 1200, 128) 0           Dilated1_Conv0[0][0]
# __________________________________________________________________________________________________
# Dilated1_Conv1 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (None, 1, 1200, 128) 0           Dilated1_Conv1[0][0]
# __________________________________________________________________________________________________
# Dilated1_Conv2 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (None, 1, 1200, 128) 0           Dilated1_Conv2[0][0]
# __________________________________________________________________________________________________
# Dilated1_Conv3 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (None, 1, 1200, 128) 0           Dilated1_Conv3[0][0]
# __________________________________________________________________________________________________
# Dilated1_Conv4 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (None, 1, 1200, 128) 0           Dilated1_Conv4[0][0]
# __________________________________________________________________________________________________
# Dilated1_Addition (Add)         (None, 1, 1200, 128) 0           time_distributed_17[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# Dilated1_Dropout (TimeDistribut (None, 1, 1200, 128) 0           Dilated1_Addition[0][0]
# __________________________________________________________________________________________________
# Dilated2_Conv0 (TimeDistributed (None, 1, 1200, 128) 114816      Dilated1_Dropout[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (None, 1, 1200, 128) 0           Dilated2_Conv0[0][0]
# __________________________________________________________________________________________________
# Dilated2_Conv1 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (None, 1, 1200, 128) 0           Dilated2_Conv1[0][0]
# __________________________________________________________________________________________________
# Dilated2_Conv2 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (None, 1, 1200, 128) 0           Dilated2_Conv2[0][0]
# __________________________________________________________________________________________________
# Dilated2_Conv3 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (None, 1, 1200, 128) 0           Dilated2_Conv3[0][0]
# __________________________________________________________________________________________________
# Dilated2_Conv4 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (None, 1, 1200, 128) 0           Dilated2_Conv4[0][0]
# __________________________________________________________________________________________________
# Dilated2_Addition (Add)         (None, 1, 1200, 128) 0           time_distributed_22[0][0]
#                                                                  Dilated1_Dropout[0][0]
# __________________________________________________________________________________________________
# Dilated2_Dropout (TimeDistribut (None, 1, 1200, 128) 0           Dilated2_Addition[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 1, 1200, 4)   516         Dilated2_Dropout[0][0]
# ==================================================================================================
# Total params: 3,145,284
# Trainable params: 3,145,284
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /home/kkotzen/miniconda3/envs/tf25/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
X = tf.random.uniform((100,1200*30*32,1), minval=0, maxval=1, dtype=tf.dtypes.float32, seed=None, name=None)
Y = tf.random.uniform((100,1200), minval=0, maxval=4, dtype=tf.dtypes.int32, seed=None, name=None)

# %%
model.fit(X, Y, batch_size=2, epochs=10)

# %%
import tensorflow as tf
from tensorflow.python.keras import Input
from tensorflow.keras.models import Model
from tensorflow.python.keras.layers import Conv1D, GlobalAveragePooling1D, AveragePooling1D, MaxPool1D, Flatten, Dense, \
    Reshape, Dropout, TimeDistributed, Add, LSTM, GRU, Bidirectional
from tensorflow.python.keras.layers import LeakyReLU

def korkalainen_model(shape, params):
    print("Building Model", end="")

    inputs = Input(shape=(shape[1], 1))
    
    X = Conv1D(64, 11, strides=1, activation='relu',  padding='same', name="Conv1_1")(inputs)
    X = Conv1D(64, 11, strides=1, activation='relu',  padding='same', name="Conv1_2")(X)
    X = MaxPool1D(2, strides=2)(X)

    X = Conv1D(128, 5, strides=1, activation='relu', padding='same', name="Conv2_1")(X)
    X = Conv1D(128, 5, strides=1, activation='relu', padding='same', name="Conv2_2")(X)
    X = MaxPool1D(2, strides=2)(X)

    X = Conv1D(256, 3, strides=1, activation='relu', padding='same', name="Conv3_1")(X)
    X = Conv1D(256, 3, strides=1, activation='relu', padding='same', name="Conv3_2")(X)
#     X = MaxPool1D(2, strides=2)(X)

#     X = Conv1D(512, 3, strides=1, activation='relu', padding='same', name="Conv4_1")(X)
#     X = Conv1D(512, 3, strides=1, activation='relu', padding='same', name="Conv4_2")(X)
    X = Reshape(target_shape=(1200, int(X.shape[1]/1200), X.shape[2]))(X)
    print(X.shape)
    X = TimeDistributed(GlobalAveragePooling1D())(X)
#     X = TimeDistributed(Flatten())(X)
    X = TimeDistributed(Dropout(0.3))(X)


    X = Bidirectional(LSTM(256, return_sequences=True, dropout=0.3, recurrent_dropout=0.5))(X)
    X = TimeDistributed(Dense(128,activation='relu'))(X)
    out = TimeDistributed(Dense(4,activation='softmax'))(X)

    model = Model(inputs=inputs, outputs=out)

#     kappa = CohenKappa2D(num_classes=4, sparse_labels=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(lr=params['learning_rate']),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  metrics=['accuracy'],
                  sample_weight_mode="temporal")
    print("Model Compiled")
    return model

# %%
in_shape = (100, 1200*30*32, 1)
model_params = {'verbose': 1, 'model_checkpoints': '/home/kkotzen/tmp/models', 'memory_time_steps': 1200, 'learning_rate': 0.0001, 'epochs': 80, 'batch_size': 1, 'es_mc': True, 'es_mc_metric': 'kappa', 'evaluation_set': 'validate', 'dropout': 0.45, 'weight_wake': 1.0, 'weight_light': 1.0, 'weight_deep': 4.0, 'weight_rem': 1.0, 'input_convs': 8, 'input_kernel': 1, 'conv_kernel': 7, 'conv_filters_base': 16, 'dense1': 128, 'use_dense2': False, 'dense2': 64, 'dilated_kernel': 7, 'use_dilated_2': True, 'use_dilated_3': False, 'l2': 0, 'l1': 0}
model = korkalainen_model(in_shape, model_params)
model.summary()
# Out:
# Building Model(None, 1200, 240, 256)
# Model Compiled
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_15 (InputLayer)        [(None, 1152000, 1)]      0
# _________________________________________________________________
# Conv1_1 (Conv1D)             (None, 1152000, 64)       768
# _________________________________________________________________
# Conv1_2 (Conv1D)             (None, 1152000, 64)       45120
# _________________________________________________________________
# max_pooling1d_39 (MaxPooling (None, 576000, 64)        0
# _________________________________________________________________
# Conv2_1 (Conv1D)             (None, 576000, 128)       41088
# _________________________________________________________________
# Conv2_2 (Conv1D)             (None, 576000, 128)       82048
# _________________________________________________________________
# max_pooling1d_40 (MaxPooling (None, 288000, 128)       0
# _________________________________________________________________
# Conv3_1 (Conv1D)             (None, 288000, 256)       98560
# _________________________________________________________________
# Conv3_2 (Conv1D)             (None, 288000, 256)       196864
# _________________________________________________________________
# reshape_14 (Reshape)         (None, 1200, 240, 256)    0
# _________________________________________________________________
# time_distributed_26 (TimeDis (None, 1200, 256)         0
# _________________________________________________________________
# time_distributed_27 (TimeDis (None, 1200, 256)         0
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 1200, 512)         1050624
# _________________________________________________________________
# time_distributed_28 (TimeDis (None, 1200, 128)         65664
# _________________________________________________________________
# time_distributed_29 (TimeDis (None, 1200, 4)           516
# =================================================================
# Total params: 1,581,252
# Trainable params: 1,581,252
# Non-trainable params: 0
# _________________________________________________________________
