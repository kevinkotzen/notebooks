# %%
# %matplotlib inline
from src.parsing.MESAParser import MESAParser
import matplotlib.pyplot as plt
import pandas as pd

# %%
dl = MESAParser()

# %%
patient = dl.get_patient_IDs_from_file()[100]
hrv = dl.load_hrv_features(patient, 'Pleth')
morph = dl.load_morphology_features(patient, 'Pleth')
all_ppg = pd.concat([morph, hrv], axis=1)
drop_columns = [col for col in ['epoch', 'sleep', 'patient', 'window'] if col in all_ppg.columns]
print(all_ppg.columns)
print(all_ppg.drop(columns=drop_columns).columns)
print(all_ppg.head(1).shape[1], all_ppg.head(1).drop(columns=drop_columns).shape[1])
# Out:
# Index(['AUCPPG', 'CP', 'DT', 'DW10', 'DW10/SW10', 'DW25', 'DW25/SW25', 'DW33',
#        'DW33/SW33', 'DW50', 'DW50/SW50', 'DW66', 'DW66/SW66', 'DW75',
#        'DW75/SW75', 'DW90', 'DW90/SW90', 'PIR', 'STT', 'SUT', 'SW10',
#        'SW10+DW10', 'SW25', 'SW25+DW25', 'SW33', 'SW33+DW33', 'SW50',
#        'SW50+DW50', 'SW66', 'SW66+DW66', 'SW75', 'SW75+DW75', 'SW90',
#        'SW90+DW90', 'duration', 'epoch', 'n_peaks', 'sys_out_curve',
#        'sys_peak/tpi-t1', 'systolic_amplitude', 'systolic_peak_time', 't1/cp',
#        'tpi', 'width_25_t1', 'width_25_tpi', 'width_50_t1', 'width_50_tpi',
#        'width_75_t1', 'width_75_tpi', 'window', 'epoch', 'AFEv', 'AFEv_filt',
#        'AVNN', 'AVNN_filt', 'CV', 'CV_filt', 'IALS', 'IALS_filt', 'IrrEv',
#        'IrrEv_filt', 'OriginCount', 'OriginCount_filt', 'PACEv', 'PACEv_filt',
#        'PAS', 'PAS_filt', 'PIP', 'PIP_filt', 'PNN20', 'PNN20_filt', 'PNN50',
#        'PNN50_filt', 'PSS', 'PSS_filt', 'RMSSD', 'RMSSD_filt', 'SD1',
# ...

# %%
plt.close()

for column in ppg_morph.columns:
    print(column)
    plt.plot(ppg_morph['epoch'], ppg_morph[column])
    plt.show()
# Out:
# AUCPPG
# CP
# DT
# DW10
# DW10/SW10
# DW25
# DW25/SW25
# DW33
# DW33/SW33
# DW50
# DW50/SW50
# DW66
# DW66/SW66
# DW75
# DW75/SW75
# DW90
# DW90/SW90
# PIR
# STT
# SUT
# SW10
# SW10+DW10
# SW25
# SW25+DW25
# SW33
# SW33+DW33
# SW50
# SW50+DW50
# SW66
# SW66+DW66
# SW75
# SW75+DW75
# SW90
# SW90+DW90
# duration
# epoch
# n_peaks
# sys_out_curve
# sys_peak/tpi-t1
# systolic_amplitude
# systolic_peak_time
# t1/cp
# tpi
# width_25_t1
# width_25_tpi
# width_50_t1
# width_50_tpi
# width_75_t1
# width_75_tpi
# window

# %%
plt.close()
ax = plt.subplot(1,1,1)
ax.plot(ecg_features["epoch"], ecg_features["SDNN_filt"], color='red')
ax.plot(ppg_features["epoch"], ppg_features["SDNN_filt"], color='green')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
