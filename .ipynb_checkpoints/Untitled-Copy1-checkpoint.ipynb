# %%
# %matplotlib widget
import sys
import os
import time
import numpy as np
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Set the GPU you wish to use here
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], enable=True)

import tensorflow_addons as tfa
from tensorflow.python.keras import Input
from tensorflow.keras.models import Sequential, Model
from tensorflow.python.keras.layers import Conv1D, GlobalAveragePooling1D, AveragePooling1D, MaxPool1D, Flatten, Dense, \
    Reshape, Dropout, TimeDistributed, Add, LSTM, GRU, Bidirectional, MaxPooling1D, Reshape
from tensorflow.python.keras.layers import LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow.python.keras as keras
tf.keras.backend.clear_session()

# %%
import tensorflow as tf
from tensorflow.python.keras import Input
from tensorflow.keras.models import Model
from tensorflow.python.keras.layers import Conv1D, GlobalAveragePooling1D, AveragePooling1D, MaxPool1D, Flatten, Dense, \
    Reshape, Dropout, TimeDistributed, Add, LSTM, GRU, Bidirectional
from tensorflow.python.keras.layers import LeakyReLU


def dilated_residual_convolution(X_in, kernel, dilations, dropout, name="", l1=0):
    X = X_in
    for i, dilation in enumerate(dilations):
        X = TimeDistributed(
            Conv1D(X_in.shape[-1], kernel_size=kernel, dilation_rate=dilation, padding='same',
                   kernel_regularizer=tf.keras.regularizers.l1(l=l1)),
            name=f"{name}_Conv{i}")(X)
        X = TimeDistributed(LeakyReLU(alpha=0.15))(X)
    X = Add(name=f"{name}_Addition")([X, X_in])
    if dropout > 0:
        X = TimeDistributed(Dropout(dropout), name=f"{name}_Dropout")(X)
    return X


def residual_convolution(X_in, kernel, filt, n_convs, name=None, l1=0):
    X = X_in
    # Residual needs 1x1 CNN
    X_residual = Conv1D(filt, 1, activation='relu', padding='same', name=f"{name}_residual_1x1Conv")(X)
    X_residual = MaxPool1D(2, strides=2, name=f"{name}_residual_Maxpool")(X_residual)

    # Convolutions and max pooling
    for i in range(n_convs):
        X = Conv1D(filt, kernel, kernel_regularizer=tf.keras.regularizers.l1(l=l1), padding='same',
                            name=f"{name}_Conv{i}")(X)
        X = LeakyReLU(alpha=0.15)(X)

    # Bring in the residual
    X = MaxPool1D(2, strides=2, name=f"{name}_Maxpool")(X)
    X = Add(name=f"{name}_residual_Add")([X, X_residual])

    return X


def convolution(X_in, kernel, filt, n_convs=1, name=None, l1=0):
    X = X_in
    for i in range(n_convs):
        X = Conv1D(filt, kernel, padding='same', kernel_regularizer=tf.keras.regularizers.l1(l=l1),
                            name=f"{name}_Conv{i}")(X)
        X = LeakyReLU(alpha=0.15)(X)
    X = MaxPool1D(2, strides=2, name=f"{name}_maxpool")(X)
    return X


def google_signal_model(shape, params):
    print("Building Model", end="")
    inputs = Input(shape=(shape[1], 1))

    X = Conv1D(params['input_convs'], params['input_kernel'], padding='same', kernel_regularizer =tf.keras.regularizers.l1(l=params['l1']), name="InputConv")(inputs)

    X = residual_convolution(X, kernel=params['conv_kernel'], filt=params['conv_filters_base'], n_convs=2, name="ConvBlock1", l1=params['l1'])
    X = residual_convolution(X, kernel=params['conv_kernel'], filt=params['conv_filters_base']*2, n_convs=2, name="ConvBlock2",l1=params['l1'])
    X = residual_convolution(X, kernel=params['conv_kernel'], filt=params['conv_filters_base']*4, n_convs=2, name="ConvBlock3",l1=params['l1'])
    X = residual_convolution(X, kernel=params['conv_kernel'], filt=params['conv_filters_base']*8, n_convs=2, name="ConvBlock4",l1=params['l1'])
    X = residual_convolution(X, kernel=params['conv_kernel'], filt=params['conv_filters_base']*16, n_convs=2, name="ConvBlock5",l1=params['l1'])
    X = residual_convolution(X, kernel=params['conv_kernel'], filt=params['conv_filters_base']*16, n_convs=2, name="ConvBlock6",l1=params['l1'])
    X = MaxPool1D(3, strides=3, name=f"Final_Maxpool")(X)
    X = Reshape(target_shape=(params['memory_time_steps'], int(X.shape[1]/params['memory_time_steps']), params['conv_filters_base']*16))(X)
    X = TimeDistributed(Flatten(), name=f"Flatten")(X)
    # X = TimeDistributed(Dropout(params['dropout']), name=f"DropoutD1")(X)
    X = TimeDistributed(Dense(units=params['dense1']), name=f"Dense1")(X)
    X = TimeDistributed(LeakyReLU(alpha=0.15))(X)
    # X = TimeDistributed(Dropout(params['dropout']), name=f"DropoutD2")(X)

    if params['use_dense2']:
        X = TimeDistributed(Dense(units=params['dense2']), name=f"Dense2")(X)
        X = TimeDistributed(LeakyReLU(alpha=0.15))(X)


    X = Reshape(target_shape=(1, X.shape[1], X.shape[2]))(X)

    X = dilated_residual_convolution(X, kernel=int(params['dilated_kernel']), dilations=[2, 4, 8, 16, 32], dropout=params['dropout'], l1=params['l1'], name="Dilated1")
    if params['use_dilated_2']:
        X = dilated_residual_convolution(X, kernel=int(params['dilated_kernel']), dilations=[2, 4, 8, 16, 32], dropout=params['dropout'], l1=params['l1'], name="Dilated2")
    if params['use_dilated_3']:
        X = dilated_residual_convolution(X, kernel=int(params['dilated_kernel']), dilations=[2, 4, 8, 16, 32], dropout=params['dropout'], l1=params['l1'], name="Dilated3")

    out = TimeDistributed(Conv1D(4, 1, activation='softmax'))(X)

    model = Model(inputs=inputs, outputs=out)

    kappa = CohenKappa2D(num_classes=4, sparse_labels=True)

    model.compile(optimizer=tf.keras.optimizers.Adam(lr=params['learning_rate']),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  metrics=['accuracy', kappa ],
                  sample_weight_mode="temporal")
    print("Model Compiled")
    return model

# %%
in_shape = (100, 1152000, 1)
model_params = {'verbose': 1, 'model_checkpoints': '/home/kkotzen/tmp/models', 'memory_time_steps': 1200, 'learning_rate': 0.0001, 'epochs': 80, 'batch_size': 1, 'es_mc': True, 'es_mc_metric': 'kappa', 'evaluation_set': 'validate', 'dropout': 0.45, 'weight_wake': 1.0, 'weight_light': 1.0, 'weight_deep': 4.0, 'weight_rem': 1.0, 'input_convs': 8, 'input_kernel': 1, 'conv_kernel': 7, 'conv_filters_base': 16, 'dense1': 128, 'use_dense2': False, 'dense2': 64, 'dilated_kernel': 7, 'use_dilated_2': True, 'use_dilated_3': False, 'l2': 0, 'l1': 0}
model = google_signal_model(in_shape, model_params)
model.summary()
# Out:
# Building ModelModel Compiled
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_31 (InputLayer)           [(None, 1152000, 1)] 0
# __________________________________________________________________________________________________
# InputConv (Conv1D)              (None, 1152000, 8)   16          input_31[0][0]
# __________________________________________________________________________________________________
# ConvBlock1_Conv0 (Conv1D)       (None, 1152000, 16)  912         InputConv[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_338 (LeakyReLU)     (None, 1152000, 16)  0           ConvBlock1_Conv0[0][0]
# __________________________________________________________________________________________________
# ConvBlock1_Conv1 (Conv1D)       (None, 1152000, 16)  1808        leaky_re_lu_338[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_339 (LeakyReLU)     (None, 1152000, 16)  0           ConvBlock1_Conv1[0][0]
# __________________________________________________________________________________________________
# ConvBlock1_residual_1x1Conv (Co (None, 1152000, 16)  144         InputConv[0][0]
# __________________________________________________________________________________________________
# ConvBlock1_Maxpool (MaxPooling1 (None, 576000, 16)   0           leaky_re_lu_339[0][0]
# __________________________________________________________________________________________________
# ConvBlock1_residual_Maxpool (Ma (None, 576000, 16)   0           ConvBlock1_residual_1x1Conv[0][0]
# __________________________________________________________________________________________________
# ConvBlock1_residual_Add (Add)   (None, 576000, 16)   0           ConvBlock1_Maxpool[0][0]
#                                                                  ConvBlock1_residual_Maxpool[0][0]
# __________________________________________________________________________________________________
# ConvBlock2_Conv0 (Conv1D)       (None, 576000, 32)   3616        ConvBlock1_residual_Add[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_340 (LeakyReLU)     (None, 576000, 32)   0           ConvBlock2_Conv0[0][0]
# __________________________________________________________________________________________________
# ConvBlock2_Conv1 (Conv1D)       (None, 576000, 32)   7200        leaky_re_lu_340[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_341 (LeakyReLU)     (None, 576000, 32)   0           ConvBlock2_Conv1[0][0]
# __________________________________________________________________________________________________
# ConvBlock2_residual_1x1Conv (Co (None, 576000, 32)   544         ConvBlock1_residual_Add[0][0]
# __________________________________________________________________________________________________
# ConvBlock2_Maxpool (MaxPooling1 (None, 288000, 32)   0           leaky_re_lu_341[0][0]
# __________________________________________________________________________________________________
# ConvBlock2_residual_Maxpool (Ma (None, 288000, 32)   0           ConvBlock2_residual_1x1Conv[0][0]
# __________________________________________________________________________________________________
# ConvBlock2_residual_Add (Add)   (None, 288000, 32)   0           ConvBlock2_Maxpool[0][0]
#                                                                  ConvBlock2_residual_Maxpool[0][0]
# __________________________________________________________________________________________________
# ConvBlock3_Conv0 (Conv1D)       (None, 288000, 64)   14400       ConvBlock2_residual_Add[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_342 (LeakyReLU)     (None, 288000, 64)   0           ConvBlock3_Conv0[0][0]
# __________________________________________________________________________________________________
# ConvBlock3_Conv1 (Conv1D)       (None, 288000, 64)   28736       leaky_re_lu_342[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_343 (LeakyReLU)     (None, 288000, 64)   0           ConvBlock3_Conv1[0][0]
# __________________________________________________________________________________________________
# ConvBlock3_residual_1x1Conv (Co (None, 288000, 64)   2112        ConvBlock2_residual_Add[0][0]
# __________________________________________________________________________________________________
# ConvBlock3_Maxpool (MaxPooling1 (None, 144000, 64)   0           leaky_re_lu_343[0][0]
# __________________________________________________________________________________________________
# ConvBlock3_residual_Maxpool (Ma (None, 144000, 64)   0           ConvBlock3_residual_1x1Conv[0][0]
# __________________________________________________________________________________________________
# ConvBlock3_residual_Add (Add)   (None, 144000, 64)   0           ConvBlock3_Maxpool[0][0]
#                                                                  ConvBlock3_residual_Maxpool[0][0]
# __________________________________________________________________________________________________
# ConvBlock4_Conv0 (Conv1D)       (None, 144000, 128)  57472       ConvBlock3_residual_Add[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_344 (LeakyReLU)     (None, 144000, 128)  0           ConvBlock4_Conv0[0][0]
# __________________________________________________________________________________________________
# ConvBlock4_Conv1 (Conv1D)       (None, 144000, 128)  114816      leaky_re_lu_344[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_345 (LeakyReLU)     (None, 144000, 128)  0           ConvBlock4_Conv1[0][0]
# __________________________________________________________________________________________________
# ConvBlock4_residual_1x1Conv (Co (None, 144000, 128)  8320        ConvBlock3_residual_Add[0][0]
# __________________________________________________________________________________________________
# ConvBlock4_Maxpool (MaxPooling1 (None, 72000, 128)   0           leaky_re_lu_345[0][0]
# __________________________________________________________________________________________________
# ConvBlock4_residual_Maxpool (Ma (None, 72000, 128)   0           ConvBlock4_residual_1x1Conv[0][0]
# __________________________________________________________________________________________________
# ConvBlock4_residual_Add (Add)   (None, 72000, 128)   0           ConvBlock4_Maxpool[0][0]
#                                                                  ConvBlock4_residual_Maxpool[0][0]
# __________________________________________________________________________________________________
# ConvBlock5_Conv0 (Conv1D)       (None, 72000, 256)   229632      ConvBlock4_residual_Add[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_346 (LeakyReLU)     (None, 72000, 256)   0           ConvBlock5_Conv0[0][0]
# __________________________________________________________________________________________________
# ConvBlock5_Conv1 (Conv1D)       (None, 72000, 256)   459008      leaky_re_lu_346[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_347 (LeakyReLU)     (None, 72000, 256)   0           ConvBlock5_Conv1[0][0]
# __________________________________________________________________________________________________
# ConvBlock5_residual_1x1Conv (Co (None, 72000, 256)   33024       ConvBlock4_residual_Add[0][0]
# __________________________________________________________________________________________________
# ConvBlock5_Maxpool (MaxPooling1 (None, 36000, 256)   0           leaky_re_lu_347[0][0]
# __________________________________________________________________________________________________
# ConvBlock5_residual_Maxpool (Ma (None, 36000, 256)   0           ConvBlock5_residual_1x1Conv[0][0]
# __________________________________________________________________________________________________
# ConvBlock5_residual_Add (Add)   (None, 36000, 256)   0           ConvBlock5_Maxpool[0][0]
#                                                                  ConvBlock5_residual_Maxpool[0][0]
# __________________________________________________________________________________________________
# ConvBlock6_Conv0 (Conv1D)       (None, 36000, 256)   459008      ConvBlock5_residual_Add[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_348 (LeakyReLU)     (None, 36000, 256)   0           ConvBlock6_Conv0[0][0]
# __________________________________________________________________________________________________
# ConvBlock6_Conv1 (Conv1D)       (None, 36000, 256)   459008      leaky_re_lu_348[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_349 (LeakyReLU)     (None, 36000, 256)   0           ConvBlock6_Conv1[0][0]
# __________________________________________________________________________________________________
# ConvBlock6_residual_1x1Conv (Co (None, 36000, 256)   65792       ConvBlock5_residual_Add[0][0]
# __________________________________________________________________________________________________
# ConvBlock6_Maxpool (MaxPooling1 (None, 18000, 256)   0           leaky_re_lu_349[0][0]
# __________________________________________________________________________________________________
# ConvBlock6_residual_Maxpool (Ma (None, 18000, 256)   0           ConvBlock6_residual_1x1Conv[0][0]
# __________________________________________________________________________________________________
# ConvBlock6_residual_Add (Add)   (None, 18000, 256)   0           ConvBlock6_Maxpool[0][0]
#                                                                  ConvBlock6_residual_Maxpool[0][0]
# __________________________________________________________________________________________________
# Final_Maxpool (MaxPooling1D)    (None, 6000, 256)    0           ConvBlock6_residual_Add[0][0]
# __________________________________________________________________________________________________
# reshape_35 (Reshape)            (None, 1200, 5, 256) 0           Final_Maxpool[0][0]
# __________________________________________________________________________________________________
# Flatten (TimeDistributed)       (None, 1200, 1280)   0           reshape_35[0][0]
# __________________________________________________________________________________________________
# Dense1 (TimeDistributed)        (None, 1200, 128)    163968      Flatten[0][0]
# __________________________________________________________________________________________________
# time_distributed_61 (TimeDistri (None, 1200, 128)    0           Dense1[0][0]
# __________________________________________________________________________________________________
# reshape_36 (Reshape)            (None, 1, 1200, 128) 0           time_distributed_61[0][0]
# __________________________________________________________________________________________________
# Dilated1_Conv0 (TimeDistributed (None, 1, 1200, 128) 114816      reshape_36[0][0]
# __________________________________________________________________________________________________
# time_distributed_62 (TimeDistri (None, 1, 1200, 128) 0           Dilated1_Conv0[0][0]
# __________________________________________________________________________________________________
# Dilated1_Conv1 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_62[0][0]
# __________________________________________________________________________________________________
# time_distributed_63 (TimeDistri (None, 1, 1200, 128) 0           Dilated1_Conv1[0][0]
# __________________________________________________________________________________________________
# Dilated1_Conv2 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_63[0][0]
# __________________________________________________________________________________________________
# time_distributed_64 (TimeDistri (None, 1, 1200, 128) 0           Dilated1_Conv2[0][0]
# __________________________________________________________________________________________________
# Dilated1_Conv3 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_64[0][0]
# __________________________________________________________________________________________________
# time_distributed_65 (TimeDistri (None, 1, 1200, 128) 0           Dilated1_Conv3[0][0]
# __________________________________________________________________________________________________
# Dilated1_Conv4 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_65[0][0]
# __________________________________________________________________________________________________
# time_distributed_66 (TimeDistri (None, 1, 1200, 128) 0           Dilated1_Conv4[0][0]
# __________________________________________________________________________________________________
# Dilated1_Addition (Add)         (None, 1, 1200, 128) 0           time_distributed_66[0][0]
#                                                                  reshape_36[0][0]
# __________________________________________________________________________________________________
# Dilated1_Dropout (TimeDistribut (None, 1, 1200, 128) 0           Dilated1_Addition[0][0]
# __________________________________________________________________________________________________
# Dilated2_Conv0 (TimeDistributed (None, 1, 1200, 128) 114816      Dilated1_Dropout[0][0]
# __________________________________________________________________________________________________
# time_distributed_67 (TimeDistri (None, 1, 1200, 128) 0           Dilated2_Conv0[0][0]
# __________________________________________________________________________________________________
# Dilated2_Conv1 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_67[0][0]
# __________________________________________________________________________________________________
# time_distributed_68 (TimeDistri (None, 1, 1200, 128) 0           Dilated2_Conv1[0][0]
# __________________________________________________________________________________________________
# Dilated2_Conv2 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_68[0][0]
# __________________________________________________________________________________________________
# time_distributed_69 (TimeDistri (None, 1, 1200, 128) 0           Dilated2_Conv2[0][0]
# __________________________________________________________________________________________________
# Dilated2_Conv3 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_69[0][0]
# __________________________________________________________________________________________________
# time_distributed_70 (TimeDistri (None, 1, 1200, 128) 0           Dilated2_Conv3[0][0]
# __________________________________________________________________________________________________
# Dilated2_Conv4 (TimeDistributed (None, 1, 1200, 128) 114816      time_distributed_70[0][0]
# __________________________________________________________________________________________________
# time_distributed_71 (TimeDistri (None, 1, 1200, 128) 0           Dilated2_Conv4[0][0]
# __________________________________________________________________________________________________
# Dilated2_Addition (Add)         (None, 1, 1200, 128) 0           time_distributed_71[0][0]
#                                                                  Dilated1_Dropout[0][0]
# __________________________________________________________________________________________________
# Dilated2_Dropout (TimeDistribut (None, 1, 1200, 128) 0           Dilated2_Addition[0][0]
# __________________________________________________________________________________________________
# time_distributed_72 (TimeDistri (None, 1, 1200, 4)   516         Dilated2_Dropout[0][0]
# ==================================================================================================
# Total params: 3,258,212
# Trainable params: 3,258,212
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
X = tf.random.uniform((100,1200*30*32,1), minval=0, maxval=1, dtype=tf.dtypes.float32, seed=None, name=None)
Y = tf.random.uniform((100,1200), minval=0, maxval=4, dtype=tf.dtypes.int32, seed=None, name=None)

# %%
model.fit(X, Y, batch_size=2, epochs=10)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 1s 125ms/step - loss: 1.3883 - accuracy: 0.2508
# Epoch 2/10
# 5/5 [==============================] - 1s 117ms/step - loss: 1.3880 - accuracy: 0.2542
# Epoch 3/10
# 5/5 [==============================] - 1s 117ms/step - loss: 1.3874 - accuracy: 0.2488
# Epoch 4/10
# 5/5 [==============================] - 1s 118ms/step - loss: 1.3868 - accuracy: 0.2530
# Epoch 5/10
# 5/5 [==============================] - 1s 117ms/step - loss: 1.3864 - accuracy: 0.2525
# Epoch 6/10
# 5/5 [==============================] - 1s 118ms/step - loss: 1.3863 - accuracy: 0.2552
# Epoch 7/10
# 5/5 [==============================] - 1s 118ms/step - loss: 1.3860 - accuracy: 0.2558
# Epoch 8/10
# 5/5 [==============================] - 1s 117ms/step - loss: 1.3859 - accuracy: 0.2550
# Epoch 9/10
# 5/5 [==============================] - 1s 117ms/step - loss: 1.3866 - accuracy: 0.2539
# Epoch 10/10
# 5/5 [==============================] - 1s 117ms/step - loss: 1.3862 - accuracy: 0.2553
